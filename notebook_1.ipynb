# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import Lipinski, Descriptors

from mining_cleaning import *

# %% [markdown]
# ## Выгружаем датасеты

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dataconHack/hackathon/main/data.csv')
drug = pd.read_csv('https://raw.githubusercontent.com/dataconHack/hackathon/main/drug_descriptors.csv')
bacterial = pd.read_csv('https://raw.githubusercontent.com/dataconHack/hackathon/main/bacterial_descriptors.csv')

# %% [markdown]
# ## Очистка датасетов

# %%
bacterial.columns
# Out:
# Index(['Tax_id', 'Bacteria', 'kingdom', 'subkingdom', 'clade', 'phylum',
#        'class', 'order', 'family', 'genus', 'species', 'gram',
#        'min_Incub_period, h', 'avg_Incub_period, h', 'max_Incub_period, h',
#        'growth_temp, C', 'biosafety_level', 'isolated_from'],
#       dtype='object')

# %%
# Список колонок, которые нужно дропнуть
data_drop_lst = ['Unnamed: 0.1', 'Unnamed: 0', 'Drug_class_drug_bank',
                 'method', 'MDR_check', 'NP_Synthesis', 'ZOI_NP', 'NP_concentration']
drug_drop_lst = ['Unnamed: 0', 'chemID', 'prefered_name']
bacterial_drop_lst = ['Tax_id', 'subkingdom', 'clade', 'phylum', 'class', 'order', 'family', 'genus', 'species', 'isolated_from']

data, drug, bacterial = drop_columns([data, drug, bacterial], [data_drop_lst, drug_drop_lst, bacterial_drop_lst])

# %%
data
# Out:
#                    Bacteria         Drug  Drug_dose  NP size_min  NP size_max  \
# 0          Escherichia coli  Amoxicillin        NaN          4.0         10.0
# 1          Escherichia coli   Penicillin        NaN          4.0         10.0
# 2          Escherichia coli  Amoxicillin        NaN         15.0         30.0
# 3          Escherichia coli   Penicillin        NaN         15.0         30.0
# 4        Micrococcus luteus   Vancomycin       30.0          5.0         30.0
# ..                      ...          ...        ...          ...          ...
# 878   Staphylococcus aureus          NaN        NaN         10.0         78.9
# 879  Acinetobacter baumanii          NaN        NaN         10.0         78.9
# 880   Enterococcus faecalis          NaN        NaN         20.0         20.0
# 881   Enterococcus faecalis          NaN        NaN         20.0         20.0
# 882   Enterococcus faecalis          NaN        NaN         20.0         20.0
#
#      NP size_avg      shape ZOI_drug ZOI_drug_NP  \
# 0           8.00  spherical      32+         32+
# 1           8.00  spherical      32+         32+
# 2          28.00  spherical      32+         32+
# 3          28.00  spherical      32+         32+
# 4          21.00  spherical        0        17+2
# ..           ...        ...      ...         ...
# 878        44.45  spherical      NaN         NaN
# 879        44.45  spherical      NaN         NaN
# 880        20.00  spherical      NaN         NaN
# 881        20.00  spherical      NaN         NaN
# 882        20.00  spherical      NaN         NaN
#
#      fold_increase_in_antibacterial_activity (%)
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                           7.02
# ..                                           ...
# 878                                          NaN
# 879                                          NaN
# 880                                          NaN
# 881                                          NaN
# 882                                          NaN
#
# [883 rows x 10 columns]

# %% [markdown]
# ## Заполнение дескрипторами

# %%
drug = fill_df_descriptors(drug)
drug
# Out:
#                drug                                             smiles  \
# 0       Amoxicillin  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 1        Penicillin  CC1(C)S[C@@H]2[C@H](NC(=O)Cc3ccccc3)C(=O)N2[C@...
# 2        Vancomycin  CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...
# 3        Gentamicin  CN[C@@H]1[C@@H](O)[C@@H](O[C@@H]2[C@@H](O)[C@H...
# 4       Ceftazidime  CC(C)(O/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=...
# 5        Ampicillin  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccccc3)C(=...
# 6         Faropenem  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C([C@H]3CCCO3...
# 7       Ceftriaxone  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(CSc3nc...
# 8        Rifampicin  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c(/C...
# 9      Azithromycin  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...
# 10  Chloramphenicol  O=C(N[C@H](CO)[C@H](O)c1ccc([N+](=O)[O-])cc1)C...
# 11  Oxytetracycline  CN(C)[C@@H]1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C...
# 12     Piperacillin  CCN1CCN(C(=O)N[C@@H](C(=O)N[C@@H]2C(=O)N3[C@@H...
# 13     Tetracycline  CN(C)[C@@H]1C(O)=C(C(N)=O)C(=O)[C@@]2(O)C(O)=C...
# 14    ciprofloxacin         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 15       Cefuroxime  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(COC(N)...
# 16     Streptomycin  CN[C@@H]1[C@H](O[C@H]2[C@H](O[C@H]3[C@H](O)[C@...
# 17   Co-trimoxazole  COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC.Cc1cc(NS(=O)(=...
# 18        Oxacillin  Cc1onc(-c2ccccc2)c1C(=O)N[C@@H]1C(=O)N2[C@@H]1...
# 19       Cefotaxime  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(COC...
# 20       Fosfomycin                          C[C@@H]1O[C@@H]1P(=O)(O)O
# 21        mupirocin  C/C(=C\C(=O)OCCCCCCCCC(=O)O)C[C@@H]1OC[C@H](C[...
# 22      Doxycycline  C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# 23   Nitrofurantoin          O=C1CN(/N=C/c2ccc([N+](=O)[O-])o2)C(=O)N1
# 24     Erythromycin  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...
# 25        cefazolin  Cc1nnc(SCC2=C(C(=O)O)N3C(=O)[C@@H](NC(=O)Cn4cn...
# 26        Cefixime   C=CC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)/C(=N\OCC(=...
# 27   Carbenicillin   CC1(C)S[C@@H]2[C@H](NC(=O)C(C(=O)O)c3ccccc3)C(...
# 28         Amikacin  NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 29     Trimethoprim                    COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC
# 30        Kanamycin  NC[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O[C@H]3O[...
# 31     Levofloxacin  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...
# 32         Imipenem  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...
# 33   Nalidixic acid                    CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 34    Fusidic acid   CC(=O)O[C@H]1C[C@@]2(C)[C@@H](C[C@@H](O)[C@H]3...
# 35    Ciprofloxacin         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 36        Polymyxin  CC(C)CCCCC(=O)N[C@@H](CCN)C(=O)N[C@H](C(=O)N[C...
# 37      Cephalexin   CC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](N)c3ccc...
# 38         Cefepime  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N...
# 39   Amphotericin B  C[C@@H]1[C@H](O)[C@@H](C)/C=C/C=C/C=C/C=C/C=C/...
# 40     Clindamycin   CCC[C@@H]1C[C@@H](C(=O)N[C@@H]([C@H]2O[C@H](SC...
# 41        colistin   CC(C)CCCCC(=O)N[C@@H](CCN)C(=O)N[C@@H](CN[C@@H...
# 42         Biapenem  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)[O-])=C(SC3Cn4cn...
# 43        Aztreonam  C[C@H]1[C@H](NC(=O)/C(=N\OC(C)(C)C(=O)O)c2csc(...
#
#     NumHDonors  NumHAcceptors  NumHeteroatoms   ExactMolWt  \
# 0            4              6               9   365.104542
# 1            1              5               8   372.054610
# 2           19             25              35  1447.430200
# 3            8             12              12   477.316249
# 4            3             11              15   546.099139
# 5            3              5               8   349.109627
# 6            2              5               7   285.067094
# 7            4             15              18   554.046058
# 8            6             15              16   822.405123
# 9            5             14              14   748.508526
# 10           3              5               9   322.012327
# 11           7             10              11   460.148180
# 12           3              7              13   517.163119
# 13           6              9              10   444.153266
# 14           2              5               7   331.133220
# 15           3              9              13   424.068884
# 16          12             15              19   581.265670
# 17           4             12              14   543.190003
# 18           2              6               9   401.104542
# 19           2             12              15   477.038884
# 20           2              2               5   138.008195
# 21           4              8               9   500.298533
# 22           6              9              11   462.163830
# 23           1              6               9   238.033819
# 24           5             14              14   733.461241
# 25           2             12              15   454.030014
# 26           4             10              14   453.041290
# 27           3              5               9   378.088557
# 28          13             17              18   585.285736
# 29           2              7               7   290.137890
# 30          11             15              15   484.238058
# 31           1              6               8   361.143784
# 32           4              5               8   299.093977
# 33           1              4               5   232.084792
# 34           3              5               6   516.345089
# 35           2              5               7   331.133220
# 36          36             36              58  2391.484204
# 37           3              5               8   347.093977
# 38           2             10              13   480.124960
# 39          12             17              18   923.487850
# 40           4              7               9   424.179871
# 41          36             36              56  2295.556975
# 42           1              7               9   350.104876
# 43           4             10              15   435.051855
#
#     MaxAbsPartialCharge  MaxPartialCharge  MinAbsPartialCharge  \
# 0              0.507967          0.327399             0.327399
# 1              1.000000          1.000000             0.547832
# 2              0.507810          0.330441             0.330441
# 3              0.387562          0.185232             0.185232
# 4              0.543191          0.349825             0.349825
# 5              0.479673          0.327399             0.327399
# 6              0.476538          0.353083             0.353083
# 7              0.488304          0.352159             0.352159
# 8              0.506736          0.312109             0.312109
# 9              0.458936          0.311188             0.311188
# 10             0.394123          0.268945             0.268945
# 11             0.509649          0.255451             0.255451
# 12             0.479673          0.327399             0.327399
# 13             0.509651          0.255451             0.255451
# 14             0.477497          0.340723             0.340723
# 15             0.476559          0.404317             0.404317
# 16             0.393567          0.187763             0.187763
# 17             0.492704          0.262638             0.262638
# 18             0.479673          0.327399             0.327399
# 19             1.000000          1.000000             0.543193
# 20             0.356452          0.356247             0.356247
# 21             0.481230          0.330185             0.330185
# 22             0.509649          0.255451             0.255451
# 23             0.433062          0.433062             0.399592
# 24             0.458937          0.311188             0.311188
# 25             0.476561          0.352158             0.352158
# 26             0.478646          0.352465             0.352465
# 27             0.480399          0.327399             0.327399
# 28             0.393567          0.248700             0.248700
# 29             0.492704          0.221432             0.221432
# 30             0.393567          0.186623             0.186623
# 31             0.486917          0.340723             0.340723
# 32             0.476539          0.352951             0.352951
# 33             0.477497          0.340725             0.340725
# 34             0.477873          0.331171             0.331171
# 35             0.477497          0.340723             0.340723
# 36             0.390717          0.245420             0.245420
# 37             0.476561          0.352115             0.352115
# 38             0.543191          0.275863             0.275863
# 39             0.480883          0.311304             0.311304
# 40             0.387508          0.237217             0.237217
# 41             0.391229          0.244773             0.244773
# 42             0.543163          0.306385             0.306385
# 43             0.478227          0.362075             0.362075
#
#     MinPartialCharge  NumRotatableBonds  NumAromaticRings  \
# 0          -0.507967                  4                 1
# 1          -0.547832                  4                 1
# 2          -0.507810                 13                 5
# 3          -0.387562                  7                 0
# 4          -0.543191                  9                 2
# 5          -0.479673                  4                 1
# 6          -0.476538                  3                 0
# 7          -0.488304                  8                 2
# 8          -0.506736                  4                 2
# 9          -0.458936                  7                 0
# 10         -0.394123                  6                 1
# 11         -0.509649                  2                 1
# 12         -0.479673                  6                 1
# 13         -0.509651                  2                 1
# 14         -0.477497                  3                 2
# 15         -0.476559                  7                 1
# 16         -0.393567                  9                 0
# 17         -0.492704                  8                 4
# 18         -0.479673                  4                 2
# 19         -0.543193                  7                 1
# 20         -0.356452                  1                 0
# 21         -0.481230                 16                 0
# 22         -0.509649                  2                 1
# 23         -0.399592                  3                 1
# 24         -0.458937                  7                 0
# 25         -0.476561                  7                 2
# 26         -0.478646                  8                 1
# 27         -0.480399                  5                 1
# 28         -0.393567                 10                 0
# 29         -0.492704                  5                 2
# 30         -0.393567                  6                 0
# 31         -0.486917                  2                 2
# 32         -0.476539                  7                 0
# 33         -0.477497                  2                 2
# 34         -0.477873                  5                 0
# 35         -0.477497                  3                 2
# 36         -0.390717                 57                 2
# 37         -0.476561                  4                 1
# 38         -0.543191                  7                 1
# 39         -0.480883                  3                 0
# 40         -0.387508                  7                 0
# 41         -0.391229                 59                 0
# 42         -0.543163                  4                 1
# 43         -0.478227                  7                 1
#
#     NumAromaticHeterocycles
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         2
# 5                         0
# 6                         0
# 7                         2
# 8                         0
# 9                         0
# 10                        0
# 11                        0
# 12                        0
# 13                        0
# 14                        1
# 15                        1
# 16                        0
# 17                        2
# 18                        1
# 19                        1
# 20                        0
# 21                        0
# 22                        0
# 23                        1
# 24                        0
# 25                        2
# 26                        1
# 27                        0
# 28                        0
# 29                        1
# 30                        0
# 31                        1
# 32                        0
# 33                        2
# 34                        0
# 35                        1
# 36                        0
# 37                        0
# 38                        1
# 39                        0
# 40                        0
# 41                        0
# 42                        1
# 43                        1

# %%
bacterial = fix_string(bacterial, 'Bacteria')
drug = fix_string(drug, 'drug')

data = fix_string(data, 'Drug')
data = fix_string(data, 'Bacteria')
# Out:
# C:\Users\artda\datacon\mining_cleaning.py:95: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[col] = df[col].str.replace('.','')

# %%
data
# Out:
#                  Bacteria        Drug  Drug_dose  NP size_min  NP size_max  \
# 0         escherichiacoli  amoxicilin        NaN          4.0         10.0
# 1         escherichiacoli   penicilin        NaN          4.0         10.0
# 2         escherichiacoli  amoxicilin        NaN         15.0         30.0
# 3         escherichiacoli   penicilin        NaN         15.0         30.0
# 4        micrococusluteus  vancomycin       30.0          5.0         30.0
# ..                    ...         ...        ...          ...          ...
# 878   staphylococusaureus         NaN        NaN         10.0         78.9
# 879  acinetobacterbaumani         NaN        NaN         10.0         78.9
# 880   enterococusfaecalis         NaN        NaN         20.0         20.0
# 881   enterococusfaecalis         NaN        NaN         20.0         20.0
# 882   enterococusfaecalis         NaN        NaN         20.0         20.0
#
#      NP size_avg      shape ZOI_drug ZOI_drug_NP  \
# 0           8.00  spherical      32+         32+
# 1           8.00  spherical      32+         32+
# 2          28.00  spherical      32+         32+
# 3          28.00  spherical      32+         32+
# 4          21.00  spherical        0        17+2
# ..           ...        ...      ...         ...
# 878        44.45  spherical      NaN         NaN
# 879        44.45  spherical      NaN         NaN
# 880        20.00  spherical      NaN         NaN
# 881        20.00  spherical      NaN         NaN
# 882        20.00  spherical      NaN         NaN
#
#      fold_increase_in_antibacterial_activity (%)
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                           7.02
# ..                                           ...
# 878                                          NaN
# 879                                          NaN
# 880                                          NaN
# 881                                          NaN
# 882                                          NaN
#
# [883 rows x 10 columns]

# %% [markdown]
# ## Объединение датасетов

# %%
df_main = zip_data(data, drug, bacterial)

# %%
# Удаляем в ZOI все символы, стоящие после + (включительно)

df_main['ZOI_drug_NP'].replace(['32+'], 32, inplace=True)
df_main['ZOI_drug_NP'].replace(['17+2'], 17, inplace=True)

df_main['ZOI_drug'].replace(['32+'], 17, inplace=True)

# %%
df_main = type_converting(df_main, ['NumHeteroatoms', 'NumHAcceptors', 'NumHDonors', 'growth_temp, C',
                                    'biosafety_level', 'ZOI_drug_NP', 'ZOI_drug', 'NumRotatableBonds',
                                    'NumAromaticRings', 'NumAromaticHeterocycles'])

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 29 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Bacteria                                     883 non-null    object
#  1   Drug                                         642 non-null    object
#  2   Drug_dose                                    577 non-null    float64
#  3   NP size_min                                  883 non-null    float64
#  4   NP size_max                                  883 non-null    float64
#  5   NP size_avg                                  883 non-null    float64
#  6   shape                                        883 non-null    object
#  7   ZOI_drug                                     627 non-null    float64
#  8   ZOI_drug_NP                                  584 non-null    float64
#  9   fold_increase_in_antibacterial_activity (%)  421 non-null    float64
#  10  smiles                                       643 non-null    object
#  11  NumHDonors                                   643 non-null    float64
#  12  NumHAcceptors                                643 non-null    float64
#  13  NumHeteroatoms                               643 non-null    float64
#  14  ExactMolWt                                   643 non-null    float64
#  15  MaxAbsPartialCharge                          643 non-null    float64
#  16  MaxPartialCharge                             643 non-null    float64
#  17  MinAbsPartialCharge                          643 non-null    float64
#  18  MinPartialCharge                             643 non-null    float64
#  19  NumRotatableBonds                            643 non-null    float64
#  20  NumAromaticRings                             643 non-null    float64
#  21  NumAromaticHeterocycles                      643 non-null    float64
#  22  kingdom                                      888 non-null    object
#  23  gram                                         875 non-null    object
#  24  min_Incub_period, h                          858 non-null    float64
#  25  avg_Incub_period, h                          888 non-null    float64
#  26  max_Incub_period, h                          858 non-null    float64
#  27  growth_temp, C                               888 non-null    float64
#  28  biosafety_level                              888 non-null    float64
# dtypes: float64(23), object(6)
# memory usage: 202.4+ KB

# %%
df_main = df_main[~df_main['Bacteria'].isna()]
df_main = df_main[~df_main['max_Incub_period, h'].isna()]

df_main = df_main[~((df_main['ZOI_drug_NP'].isna()))]
df_main = df_main[~((df_main['ZOI_drug_NP'].isna()) & (df_main['ZOI_drug'].isna()))]
df_main = df_main[~((df_main['ZOI_drug'].isna()))]

df_main = df_main[~df_main['ExactMolWt'].isna()]

df_main = df_main[~df_main['ZOI_drug_NP'].isna()]

# %%
df_main
# Out:
#                   Bacteria        Drug  Drug_dose  NP size_min  NP size_max  \
# 0          escherichiacoli  amoxicilin        NaN          4.0         10.0
# 1          escherichiacoli   penicilin        NaN          4.0         10.0
# 2          escherichiacoli  amoxicilin        NaN         15.0         30.0
# 3          escherichiacoli   penicilin        NaN         15.0         30.0
# 4         micrococusluteus  vancomycin       30.0          5.0         30.0
# ..                     ...         ...        ...          ...          ...
# 579    staphylococusaureus   penicilin        NaN          4.0         10.0
# 580  pseudomonasaeruginosa   mupirocin        NaN          5.0         80.0
# 581    pasteurelamultocida   penicilin        NaN          4.0         10.0
# 582    pasteurelamultocida   penicilin        NaN         15.0         30.0
# 583        escherichiacoli    neomycin        NaN          5.0         80.0
#
#      NP size_avg      shape  ZOI_drug  ZOI_drug_NP  \
# 0            8.0  spherical   17.0000       32.000
# 1            8.0  spherical   17.0000       32.000
# 2           28.0  spherical   17.0000       32.000
# 3           28.0  spherical   17.0000       32.000
# 4           21.0  spherical    0.0000       17.000
# ..           ...        ...       ...          ...
# 579          8.0  spherical    1.0000        0.125
# 580         60.0  spherical    0.3125        0.100
# 581          8.0  spherical    0.0300        0.030
# 582         28.0  spherical    0.0300        0.030
# 583         60.0  spherical    2.5000        0.000
#
#      fold_increase_in_antibacterial_activity (%)  ... NumRotatableBonds  \
# 0                                            NaN  ...               4.0
# 1                                            NaN  ...               4.0
# 2                                            NaN  ...               4.0
# 3                                            NaN  ...               4.0
# 4                                           7.02  ...              13.0
# ..                                           ...  ...               ...
# 579                                          NaN  ...               4.0
# 580                                          NaN  ...               4.0
# 581                                          NaN  ...               7.0
# 582                                          NaN  ...               7.0
# 583                                          NaN  ...               2.0
#
#      NumAromaticRings  NumAromaticHeterocycles   kingdom  gram  \
# 0                 1.0                      0.0  Bacteria     n
# 1                 1.0                      0.0  Bacteria     n
# 2                 1.0                      0.0  Bacteria     n
# 3                 1.0                      0.0  Bacteria     n
# 4                 5.0                      0.0  Bacteria     p
# ..                ...                      ...       ...   ...
# 579               1.0                      0.0  Bacteria     p
# 580               1.0                      0.0  Bacteria     n
# 581               0.0                      0.0  Bacteria     p
# 582               0.0                      0.0  Bacteria     n
# 583               2.0                      1.0  Bacteria     n
#
#      min_Incub_period, h  avg_Incub_period, h  max_Incub_period, h  \
# 0                   48.0                 84.0                120.0
# 1                   48.0                 84.0                120.0
# 2                   48.0                 84.0                120.0
# 3                   48.0                 84.0                120.0
# 4                  240.0                288.0                336.0
# ..                   ...                  ...                  ...
# 579                 24.0                 36.0                 48.0
# 580                 12.0                 18.0                 24.0
# 581                 24.0                 36.0                 48.0
# 582                 24.0                 48.0                 72.0
# 583                 12.0                 18.0                 24.0
#
#      growth_temp, C  biosafety_level
# 0              37.0              2.0
# 1              37.0              2.0
# 2              37.0              2.0
# 3              37.0              2.0
# 4              30.0              1.0
# ..              ...              ...
# 579            37.0              2.0
# 580            37.0              2.0
# 581            37.0              2.0
# 582            37.0              2.0
# 583            37.0              2.0
#
# [537 rows x 29 columns]

# %%
df_main.columns
# Out:
# Index(['Bacteria', 'Drug', 'Drug_dose', 'NP size_min', 'NP size_max',
#        'NP size_avg', 'shape', 'ZOI_drug', 'ZOI_drug_NP',
#        'fold_increase_in_antibacterial_activity (%)', 'smiles', 'NumHDonors',
#        'NumHAcceptors', 'NumHeteroatoms', 'ExactMolWt', 'MaxAbsPartialCharge',
#        'MaxPartialCharge', 'MinAbsPartialCharge', 'MinPartialCharge',
#        'NumRotatableBonds', 'NumAromaticRings', 'NumAromaticHeterocycles',
#        'kingdom', 'gram', 'min_Incub_period, h', 'avg_Incub_period, h',
#        'max_Incub_period, h', 'growth_temp, C', 'biosafety_level'],
#       dtype='object')

# %%
#ONE-HOT ENCODING ПРЕОБРАЗОВАНИЕ


#Столбец ['shape']

df_main['shape_spherical'] = df_main['shape']	
df_main['shape_nanorods_and_triangles'] = df_main['shape']
df_main['shape_triangular'] = df_main['shape']
df_main = df_main.drop('shape', axis=1)

df_main['shape_spherical'].replace(['nanorods and triangles', 'triangular'], 0, inplace=True)
df_main['shape_spherical'].replace(['spherical'], 1, inplace=True)

df_main['shape_nanorods_and_triangles'].replace(['spherical', 'triangular'], 0, inplace=True)
df_main['shape_nanorods_and_triangles'].replace(['nanorods and triangles'], 1, inplace=True)

df_main['shape_triangular'].replace(['nanorods and triangles', 'spherical'], 0, inplace=True)
df_main['shape_triangular'].replace(['triangular'], 1, inplace=True)

#Столбец ['gram']

df_main['gram_p'] = df_main['gram']	
df_main = df_main.drop('gram', axis=1)

df_main['gram_p'].replace(['n', np.nan], 0, inplace=True)
df_main['gram_p'].replace(['p'], 1, inplace=True)

# %%
df_main
# Out:
#                   Bacteria        Drug  Drug_dose  NP size_min  NP size_max  \
# 0          escherichiacoli  amoxicilin        NaN          4.0         10.0
# 1          escherichiacoli   penicilin        NaN          4.0         10.0
# 2          escherichiacoli  amoxicilin        NaN         15.0         30.0
# 3          escherichiacoli   penicilin        NaN         15.0         30.0
# 4         micrococusluteus  vancomycin       30.0          5.0         30.0
# ..                     ...         ...        ...          ...          ...
# 579    staphylococusaureus   penicilin        NaN          4.0         10.0
# 580  pseudomonasaeruginosa   mupirocin        NaN          5.0         80.0
# 581    pasteurelamultocida   penicilin        NaN          4.0         10.0
# 582    pasteurelamultocida   penicilin        NaN         15.0         30.0
# 583        escherichiacoli    neomycin        NaN          5.0         80.0
#
#      NP size_avg  ZOI_drug  ZOI_drug_NP  \
# 0            8.0   17.0000       32.000
# 1            8.0   17.0000       32.000
# 2           28.0   17.0000       32.000
# 3           28.0   17.0000       32.000
# 4           21.0    0.0000       17.000
# ..           ...       ...          ...
# 579          8.0    1.0000        0.125
# 580         60.0    0.3125        0.100
# 581          8.0    0.0300        0.030
# 582         28.0    0.0300        0.030
# 583         60.0    2.5000        0.000
#
#      fold_increase_in_antibacterial_activity (%)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                           7.02
# ..                                           ...
# 579                                          NaN
# 580                                          NaN
# 581                                          NaN
# 582                                          NaN
# 583                                          NaN
#
#                                                 smiles  ...   kingdom  \
# 0    CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 1    CC1(C)S[C@@H]2[C@H](NC(=O)Cc3ccccc3)C(=O)N2[C@...  ...  Bacteria
# 2    CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 3    CC1(C)S[C@@H]2[C@H](NC(=O)Cc3ccccc3)C(=O)N2[C@...  ...  Bacteria
# 4    CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...  ...  Bacteria
# ..                                                 ...  ...       ...
# 579  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 580  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 581  CN[C@@H]1[C@@H](O)[C@@H](O[C@@H]2[C@@H](O)[C@H...  ...  Bacteria
# 582  CN[C@@H]1[C@@H](O)[C@@H](O[C@@H]2[C@@H](O)[C@H...  ...  Bacteria
# 583  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...  ...  Bacteria
#
#      min_Incub_period, h  avg_Incub_period, h  max_Incub_period, h  \
# 0                   48.0                 84.0                120.0
# 1                   48.0                 84.0                120.0
# 2                   48.0                 84.0                120.0
# 3                   48.0                 84.0                120.0
# 4                  240.0                288.0                336.0
# ..                   ...                  ...                  ...
# 579                 24.0                 36.0                 48.0
# 580                 12.0                 18.0                 24.0
# 581                 24.0                 36.0                 48.0
# 582                 24.0                 48.0                 72.0
# 583                 12.0                 18.0                 24.0
#
#      growth_temp, C  biosafety_level  shape_spherical  \
# 0              37.0              2.0                1
# 1              37.0              2.0                1
# 2              37.0              2.0                1
# 3              37.0              2.0                1
# 4              30.0              1.0                1
# ..              ...              ...              ...
# 579            37.0              2.0                1
# 580            37.0              2.0                1
# 581            37.0              2.0                1
# 582            37.0              2.0                1
# 583            37.0              2.0                1
#
#      shape_nanorods_and_triangles  shape_triangular  gram_p
# 0                               0                 0       0
# 1                               0                 0       0
# 2                               0                 0       0
# 3                               0                 0       0
# 4                               0                 0       1
# ..                            ...               ...     ...
# 579                             0                 0       1
# 580                             0                 0       0
# 581                             0                 0       1
# 582                             0                 0       0
# 583                             0                 0       0
#
# [537 rows x 31 columns]

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 537 entries, 0 to 583
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Bacteria                                     537 non-null    object
#  1   Drug                                         537 non-null    object
#  2   Drug_dose                                    423 non-null    float64
#  3   NP size_min                                  537 non-null    float64
#  4   NP size_max                                  537 non-null    float64
#  5   NP size_avg                                  537 non-null    float64
#  6   ZOI_drug                                     537 non-null    float64
#  7   ZOI_drug_NP                                  537 non-null    float64
#  8   fold_increase_in_antibacterial_activity (%)  394 non-null    float64
#  9   smiles                                       537 non-null    object
#  10  NumHDonors                                   537 non-null    float64
#  11  NumHAcceptors                                537 non-null    float64
#  12  NumHeteroatoms                               537 non-null    float64
#  13  ExactMolWt                                   537 non-null    float64
#  14  MaxAbsPartialCharge                          537 non-null    float64
#  15  MaxPartialCharge                             537 non-null    float64
#  16  MinAbsPartialCharge                          537 non-null    float64
#  17  MinPartialCharge                             537 non-null    float64
#  18  NumRotatableBonds                            537 non-null    float64
#  19  NumAromaticRings                             537 non-null    float64
#  20  NumAromaticHeterocycles                      537 non-null    float64
#  21  kingdom                                      537 non-null    object
#  22  min_Incub_period, h                          537 non-null    float64
#  23  avg_Incub_period, h                          537 non-null    float64
#  24  max_Incub_period, h                          537 non-null    float64
#  25  growth_temp, C                               537 non-null    float64
#  26  biosafety_level                              537 non-null    float64
#  27  shape_spherical                              537 non-null    int64
#  28  shape_nanorods_and_triangles                 537 non-null    int64
#  29  shape_triangular                             537 non-null    int64
#  30  gram_p                                       537 non-null    int64
# dtypes: float64(23), int64(4), object(4)
# memory usage: 134.2+ KB

# %%
df_main = df_main[df_main['kingdom']=='Bacteria']

# %%
df_main
# Out:
#                   Bacteria        Drug  Drug_dose  NP size_min  NP size_max  \
# 0          escherichiacoli  amoxicilin        NaN          4.0         10.0
# 1          escherichiacoli   penicilin        NaN          4.0         10.0
# 2          escherichiacoli  amoxicilin        NaN         15.0         30.0
# 3          escherichiacoli   penicilin        NaN         15.0         30.0
# 4         micrococusluteus  vancomycin       30.0          5.0         30.0
# ..                     ...         ...        ...          ...          ...
# 579    staphylococusaureus   penicilin        NaN          4.0         10.0
# 580  pseudomonasaeruginosa   mupirocin        NaN          5.0         80.0
# 581    pasteurelamultocida   penicilin        NaN          4.0         10.0
# 582    pasteurelamultocida   penicilin        NaN         15.0         30.0
# 583        escherichiacoli    neomycin        NaN          5.0         80.0
#
#      NP size_avg  ZOI_drug  ZOI_drug_NP  \
# 0            8.0   17.0000       32.000
# 1            8.0   17.0000       32.000
# 2           28.0   17.0000       32.000
# 3           28.0   17.0000       32.000
# 4           21.0    0.0000       17.000
# ..           ...       ...          ...
# 579          8.0    1.0000        0.125
# 580         60.0    0.3125        0.100
# 581          8.0    0.0300        0.030
# 582         28.0    0.0300        0.030
# 583         60.0    2.5000        0.000
#
#      fold_increase_in_antibacterial_activity (%)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                           7.02
# ..                                           ...
# 579                                          NaN
# 580                                          NaN
# 581                                          NaN
# 582                                          NaN
# 583                                          NaN
#
#                                                 smiles  ...   kingdom  \
# 0    CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 1    CC1(C)S[C@@H]2[C@H](NC(=O)Cc3ccccc3)C(=O)N2[C@...  ...  Bacteria
# 2    CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 3    CC1(C)S[C@@H]2[C@H](NC(=O)Cc3ccccc3)C(=O)N2[C@...  ...  Bacteria
# 4    CN[C@H](CC(C)C)C(=O)N[C@H]1C(=O)N[C@@H](CC(N)=...  ...  Bacteria
# ..                                                 ...  ...       ...
# 579  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 580  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...  ...  Bacteria
# 581  CN[C@@H]1[C@@H](O)[C@@H](O[C@@H]2[C@@H](O)[C@H...  ...  Bacteria
# 582  CN[C@@H]1[C@@H](O)[C@@H](O[C@@H]2[C@@H](O)[C@H...  ...  Bacteria
# 583  C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)...  ...  Bacteria
#
#      min_Incub_period, h  avg_Incub_period, h  max_Incub_period, h  \
# 0                   48.0                 84.0                120.0
# 1                   48.0                 84.0                120.0
# 2                   48.0                 84.0                120.0
# 3                   48.0                 84.0                120.0
# 4                  240.0                288.0                336.0
# ..                   ...                  ...                  ...
# 579                 24.0                 36.0                 48.0
# 580                 12.0                 18.0                 24.0
# 581                 24.0                 36.0                 48.0
# 582                 24.0                 48.0                 72.0
# 583                 12.0                 18.0                 24.0
#
#      growth_temp, C  biosafety_level  shape_spherical  \
# 0              37.0              2.0                1
# 1              37.0              2.0                1
# 2              37.0              2.0                1
# 3              37.0              2.0                1
# 4              30.0              1.0                1
# ..              ...              ...              ...
# 579            37.0              2.0                1
# 580            37.0              2.0                1
# 581            37.0              2.0                1
# 582            37.0              2.0                1
# 583            37.0              2.0                1
#
#      shape_nanorods_and_triangles  shape_triangular  gram_p
# 0                               0                 0       0
# 1                               0                 0       0
# 2                               0                 0       0
# 3                               0                 0       0
# 4                               0                 0       1
# ..                            ...               ...     ...
# 579                             0                 0       1
# 580                             0                 0       0
# 581                             0                 0       1
# 582                             0                 0       0
# 583                             0                 0       0
#
# [535 rows x 31 columns]

# %%
df_main = df_main.drop('fold_increase_in_antibacterial_activity (%)',axis = 1)

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 535 entries, 0 to 583
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Bacteria                      535 non-null    object
#  1   Drug                          535 non-null    object
#  2   Drug_dose                     421 non-null    float64
#  3   NP size_min                   535 non-null    float64
#  4   NP size_max                   535 non-null    float64
#  5   NP size_avg                   535 non-null    float64
#  6   ZOI_drug                      535 non-null    float64
#  7   ZOI_drug_NP                   535 non-null    float64
#  8   smiles                        535 non-null    object
#  9   NumHDonors                    535 non-null    float64
#  10  NumHAcceptors                 535 non-null    float64
#  11  NumHeteroatoms                535 non-null    float64
#  12  ExactMolWt                    535 non-null    float64
#  13  MaxAbsPartialCharge           535 non-null    float64
#  14  MaxPartialCharge              535 non-null    float64
#  15  MinAbsPartialCharge           535 non-null    float64
#  16  MinPartialCharge              535 non-null    float64
#  17  NumRotatableBonds             535 non-null    float64
#  18  NumAromaticRings              535 non-null    float64
#  19  NumAromaticHeterocycles       535 non-null    float64
#  20  kingdom                       535 non-null    object
#  21  min_Incub_period, h           535 non-null    float64
#  22  avg_Incub_period, h           535 non-null    float64
#  23  max_Incub_period, h           535 non-null    float64
#  24  growth_temp, C                535 non-null    float64
#  25  biosafety_level               535 non-null    float64
#  26  shape_spherical               535 non-null    int64
#  27  shape_nanorods_and_triangles  535 non-null    int64
#  28  shape_triangular              535 non-null    int64
#  29  gram_p                        535 non-null    int64
# dtypes: float64(22), int64(4), object(4)
# memory usage: 129.6+ KB

# %%
df_main = df_main.drop(['Bacteria', 'Drug', 'smiles', 'kingdom', 'Drug_dose'], axis=1)

# %%
df_main
# Out:
#      NP size_min  NP size_max  NP size_avg  ZOI_drug  ZOI_drug_NP  NumHDonors  \
# 0            4.0         10.0          8.0   17.0000       32.000         4.0
# 1            4.0         10.0          8.0   17.0000       32.000         1.0
# 2           15.0         30.0         28.0   17.0000       32.000         4.0
# 3           15.0         30.0         28.0   17.0000       32.000         1.0
# 4            5.0         30.0         21.0    0.0000       17.000        19.0
# ..           ...          ...          ...       ...          ...         ...
# 579          4.0         10.0          8.0    1.0000        0.125         4.0
# 580          5.0         80.0         60.0    0.3125        0.100         4.0
# 581          4.0         10.0          8.0    0.0300        0.030         8.0
# 582         15.0         30.0         28.0    0.0300        0.030         8.0
# 583          5.0         80.0         60.0    2.5000        0.000         1.0
#
#      NumHAcceptors  NumHeteroatoms   ExactMolWt  MaxAbsPartialCharge  ...  \
# 0              6.0             9.0   365.104542             0.507967  ...
# 1              5.0             8.0   372.054610             1.000000  ...
# 2              6.0             9.0   365.104542             0.507967  ...
# 3              5.0             8.0   372.054610             1.000000  ...
# 4             25.0            35.0  1447.430200             0.507810  ...
# ..             ...             ...          ...                  ...  ...
# 579            6.0             9.0   365.104542             0.507967  ...
# 580            6.0             9.0   365.104542             0.507967  ...
# 581           12.0            12.0   477.316249             0.387562  ...
# 582           12.0            12.0   477.316249             0.387562  ...
# 583            6.0             8.0   361.143784             0.486917  ...
#
#      NumAromaticHeterocycles  min_Incub_period, h  avg_Incub_period, h  \
# 0                        0.0                 48.0                 84.0
# 1                        0.0                 48.0                 84.0
# 2                        0.0                 48.0                 84.0
# 3                        0.0                 48.0                 84.0
# 4                        0.0                240.0                288.0
# ..                       ...                  ...                  ...
# 579                      0.0                 24.0                 36.0
# 580                      0.0                 12.0                 18.0
# 581                      0.0                 24.0                 36.0
# 582                      0.0                 24.0                 48.0
# 583                      1.0                 12.0                 18.0
#
#      max_Incub_period, h  growth_temp, C  biosafety_level  shape_spherical  \
# 0                  120.0            37.0              2.0                1
# 1                  120.0            37.0              2.0                1
# 2                  120.0            37.0              2.0                1
# 3                  120.0            37.0              2.0                1
# 4                  336.0            30.0              1.0                1
# ..                   ...             ...              ...              ...
# 579                 48.0            37.0              2.0                1
# 580                 24.0            37.0              2.0                1
# 581                 48.0            37.0              2.0                1
# 582                 72.0            37.0              2.0                1
# 583                 24.0            37.0              2.0                1
#
#      shape_nanorods_and_triangles  shape_triangular  gram_p
# 0                               0                 0       0
# 1                               0                 0       0
# 2                               0                 0       0
# 3                               0                 0       0
# 4                               0                 0       1
# ..                            ...               ...     ...
# 579                             0                 0       1
# 580                             0                 0       0
# 581                             0                 0       1
# 582                             0                 0       0
# 583                             0                 0       0
#
# [535 rows x 25 columns]

# %%
df_main.to_csv('df_result_2.csv', index=False)
